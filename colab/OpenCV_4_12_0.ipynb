# %%
# 下載事先以編譯好的 OpenCV 4.12.0
# !gdown --id 1MGW04RnidSD-e5FfLLpn1e4PQYk5Re4m
# 解壓縮
# !unzip opencv-4.12.0.zip
# 安裝
# !cd opencv/build && sudo make install
# 驗證安裝成功
# !pkg-config --modversion opencv4
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1MGW04RnidSD-e5FfLLpn1e4PQYk5Re4m
# From (redirected): https://drive.google.com/uc?id=1MGW04RnidSD-e5FfLLpn1e4PQYk5Re4m&confirm=t&uuid=57ec8493-af74-4e4a-aa00-f63475baaf7d
# To: /content/opencv-4.12.0.zip
# 100% 1.33G/1.33G [00:18<00:00, 71.5MB/s]

# %%
# %%writefile test.cpp
# #include <opencv2/opencv.hpp>
# #include <iostream>
# using namespace cv;
# int main() {
#     std::cout << "OpenCV version: " << CV_VERSION << std::endl;
#     return 0;
# }
# Out:
# Writing test.cpp

# %%
# !g++ test.cpp -o test `pkg-config --cflags --libs opencv4`
# !./test
# Out:
# OpenCV version: 4.12.0
